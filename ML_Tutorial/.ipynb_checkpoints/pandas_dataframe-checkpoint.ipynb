# %%
import pandas as pd
#read_csv is a method for importing any csv file in your working enviroment
nba=pd.read_csv('nba.csv')
#Here we are not using squeeze or uscols type attribute and 
#by looking at the data set it is clear that it contains missing value NaN
#we are going to pre process this before actual modelling.
nba.head()

# %%
nba.index
nba.shape
nba.dtypes
# # # # # # # #Below are some attributes which are made for Dataframes only
nba.columns
nba.axes
# nba.info
nba.info()

# %% [markdown]
# # shared method and column access in pandas

# %%
import pandas as pd
rev=pd.read_csv('revenue.csv', index_col='Date')
rev.head()

# %%
rev.sum() #Here data is added in terms of column wise
rev.sum(axis=0)
rev.sum(axis='index')

# %%
rev.sum(axis=1)
rev.sum(axis='columns')

# %%
nba=pd.read_csv('nba.csv')
nba.head()

#If i want to extract data column wise
# type(nba.Salary) #Its data type is series as it is a single dimension array it works properly when there is no space in column name

# %%
type(nba.Team)

# %%
# nba['Name'] #It is more accurate as it works for those column also which have space in there name
nba.Name

# %%
# nba[['Team', 'Name']]
select=['Team', 'Name']
nba[select]

# %% [markdown]
# # Add new column to data frames

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba['Sports']='Basket Ball' #One method to add column but by this column is added at the last
nba.head()

# %%
nba=pd.read_csv('nba.csv')
#Insert method : any specific place you may add your column
nba.insert(3, column="League", value="IPL")
nba.League[[0,1]]=["Hello","test"]
nba.head()

# %% [markdown]
# # BroadCasting operation in pandas

# %%
#Broadcasting : means to perform operation in whole series of a column
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
# nba['Salary'].sub(50000)
# nba['Salary']-50000


# nba['Age'].add(5)
# nba['Age']+5


# nba['Weight'].mul(0.453)
# nba['Weight']*0.453



nba["Weight in KG"]=nba['Weight']*0.453592
nba.head()

# %% [markdown]
# # Drops Rows with Null Values

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.tail()

# %%
# nba.dropna()
# nba.dropna(how='any')
nba.dropna(how='all', inplace=True)
nba.tail()

# %%
nba.dropna(axis=1, inplace=True) #It deletes column which consists NaN
nba.head()

# %%
nba.dropna(subset=['Salary'])

# %% [markdown]
# # fillna method for Null Values

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.fillna(0).head()
nba.head()

# %%
nba['Salary']
nba.fillna(0, inplace=True)
nba.head()

# %%
nba['College'].fillna('No College', inplace=True)
nba

# %% [markdown]
# # sort_values() method in Data Frames

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.sort_values('Name', ascending=False).head()

# %%
nba.sort_values('Age')
nba.sort_values('Age', ascending=False)

# %%
nba.sort_values('Salary') #NaN values would arrange at the end
# nba.sort_values('Salary', na_position='last')
nba.sort_values('Salary', na_position='first')

# %% [markdown]
# # sortvalues() for multi columns in pandas

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
#Sorting item for any column(Team, Name), ascending=False makes sorting in decending order
nba.sort_values(['Team', 'Name'])
# nba.sort_values(['Team', 'Name'], ascending=[True,False])

# %% [markdown]
# # rank() method in pandas

# %%
import pandas as pd
nba=pd.read_csv('nba.csv').dropna(how='all')
nba['Salary']=nba['Salary'].fillna(0).astype('int')
nba.head()

# %%
#I want to decide on the basis of salary, that whose salary is highest comes at rank 1 and so on..
nba['Salary'].rank()
# nba['Salary'][91]
nba['Salary'].rank(ascending=False).astype(int)
nba['Salary Rank']=nba['Salary'].rank(ascending=False).astype(int)
nba.sort_values(by='Salary', ascending=False)
# nba.head()

# %% [markdown]
# # Filtering DataFrames in pandas

# %%
import pandas as pd
df=pd.read_csv('employees.csv')
df.head()

# %%
df.info() #at the end size is there, when we look at the output it is claer that start date and last login time data type is object, but actually they are object iof adte time same as in Senior management has object type but actually it is bool and if correct data type is not there then more memory is required

# %%
df['Start Date']

# %%
# pd.to_datetime(df['Start Date'])
df['Start Date']=pd.to_datetime(df['Start Date'])

# %%
df['Last Login Time'].head()

# %%
# pd.to_datetime(df['Last Login Time'])
df['Last Login Time']=pd.to_datetime(df['Last Login Time'])

# %%
df['Senior Management']=df['Senior Management'].astype(bool)

# %%
df['Gender']=df['Gender'].astype('category')

# %%
df.info()

# %%
#date time can be converted by attribute parse_date available in read_csv method
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.info()

# %% [markdown]
# # Filtering a dataframe based on condition

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()

# %%
#If i want to apply condition on gender that i want only those value in gender series which are of male category
# df['Gender']
# df['mask']=df['Gender']=='Male'
# df
# df['mask']
df[df['Gender']=='Female'] #This will extract only those value in a column whose value are male

# %%
df['mask1']=df['Team']=='Finance'
df['mask2']=df['Gender']=='Male'
df
# df['Filter']=df[mask1 & mask2]
# df[mask1]
# df[df['Team']=='Finance']

# %%
mask=df['Senior Management']
# df[df['Senior Management']] #As senior management data is already in boolean so it can be done directly'
df[mask]

# %%
mask= df['Team'] != 'Marketing'
df[mask]
# df[df['Team'] != 'Marketing'] #condition for not equal to.

# %%
df[df['Salary']>110000]

# %% [markdown]
# # Filter Data Frame with AND & OR Operators

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-17 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-17 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-17 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-04-17 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-04-17 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
mask1=df['Gender']=='Male'
# mask1
mask2=df['Team']=='Marketing'

df[mask1 & mask2]
# print(mask1 & mask2)

# df[mask1 & mask2].head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Dougl
# 994     George   Male 2013-06-21 2021-04-17 17:47:00   98874    4.479
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# 26                True  Marketing
# 74               False  Marketing
# 77                True  Marketing
# 101               True  Marketing
# 104              False  Marketing
# 112              False  Marketing
# 119              False  Marketing
# 150              False  Marketing
# 187              False  Marketing
# 204               True  Marketing
# 216              False  Marketing
# 252               True  Marketing
# 274               True  Marketing
# 293              False  Marketing
# 309              False  Marketing
# 327               True  Marketing
# 353               True  Marketing
# 403              False  Marketing
# 413               True  Marketing
# 452               True  Marketing
# 454               True  Marketing
# 461              False  Marketing
# 464              False  Marketing
# 484              False  Marketing
# 496               True  Marketing
# 503               True  Marketing
# 544               True  Marketing
# 550               True  Marketing
# 556               True  Marketing
# 571              False  Marketing
# 581              False  Marketing
# 696               True  Marketing
# 722               True  Marketing
# 798               True  Marketing
# 860              False  Marketing
# 867              False  Marketing
# 899               True  Marketing
# 947               True  Marketing
# 994               True  Marketing

# %%
mask3=df['Senior Management']
mask4=df['Start Date']< '1990-01-01'

df[mask3 | mask4]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-04-17 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-04-17 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2021-04-17 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-04-17 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2021-04-17 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2021-04-17 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2021-04-17 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2021-04-17 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2021-04-17 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2021-04-17 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %%
mask5=df['First Name']=='Robert'
mask6=df['Team']=='Client Services'
mask7=df['Start Date']>'2016-06-01'

df[(mask5 & mask6) | mask7]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2021-04-17 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2021-04-17 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2021-04-17 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2021-04-17 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# # isin() method in pandas

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-17 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-17 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-17 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-04-17 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-04-17 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
mask1=df['Team']=='Legal'
mask2=df['Team']=='Sales'
mask3=df['Team']=='Product'

df[mask1 | mask2 | mask3].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2021-04-17 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2021-04-17 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2021-04-17 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2021-04-17 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2021-04-17 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
#As in above case it is claer that it requires same code for many times so it can be deal with the help of isin() method as in this case we are able to pass multiple arguments

df['Team'].isin(['Legal', 'Sales', 'Product'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
mask=df['Team'].isin(['Legal', 'Sales', 'Product'])
df[mask] #It is claer that we does not required multiple lines of asme type
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2021-04-17 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-04-17 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2021-04-17 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2021-04-17 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2021-04-17 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2021-04-17 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2021-04-17 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2021-04-17 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2021-04-17 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2021-04-17 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# # isnull(), notnull() ,between() and duplicate() method in panda

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-17 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-17 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-17 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-04-17 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-04-17 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
#isnull() if you want to extract null values
mask=df['Team'].isnull()
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2021-04-17 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2021-04-17 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2021-04-17 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2021-04-17 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2021-04-17 23:00:00  128771    8.309
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
mask1=df['Team'].isnull()
mask2=df['Gender'].isnull()


df [ mask1 & mask2]
# df[df['Team'].notnull()]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 91       James    NaN 2005-01-26 2021-04-17 23:00:00  128771    8.309
# 669     Joseph    NaN 1982-03-28 2021-04-17 13:05:00   86564   11.879
# 826        NaN    NaN 1988-08-01 2021-04-17 01:35:00   87103    5.665
# 855    Phillip    NaN 2003-10-20 2021-04-17 11:09:00   89700    2.277
#
#      Senior Management Team
# 91               False  NaN
# 669               True  NaN
# 826               True  NaN
# 855               True  NaN

# %%
#between()
# df['Salary'].between(60000, 70000)
df[df['Salary'].between(60000, 70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-04-17 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2021-04-17 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2021-04-17 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2021-04-17 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2021-04-17 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2021-04-17 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2021-04-17 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2021-04-17 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2021-04-17 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2021-04-17 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
df['Bonus %'].between(2.0, 5.0)
df[df['Bonus %'].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 
#
#      Senior Management                  Team
# 27               False                 Legal
# 75                True       Human Resources
# 88                True                 Legal
# 116               True                 Legal
# 148               True                 Sales
# 166               True                 Sales
# 172              False               Finance
# 220               True             Marketing
# 245              False           Engineering
# 277              False                 Sales
# 313               True                 Legal
# 328               True               Finance
# 339               True       Human Resources
# 537               True  Business Development
# 552               True               Product
# 603               True  Business Development
# 639               True       Client Services
# 704              False          Distribution
# 725               True               Finance
# 766              False       Human Resources
# 771               True               Product
# 783               True               Product
# 891              False               Finance
# 895              False  Business Development
# 909              False               Product
# 923              False  Business Development
# 989              False                 Legal

# %%
#duplicate() method
df.sort_values('First Name', inplace=True)
# df['First Name']=df.sort_values('First Name')
df['First Name']
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
df['First Name'].duplicated(keep='last') #it says that first value is not duplicate as in parameter it has keep=first you may change it to last also
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
 df[df['First Name'].duplicated(keep=False)].head()

# %%
#drop duplicate method\
len(df)
# Out:
# 1000

# %%
df.drop_duplicates(subset=['First Name'], keep='first')
len( df.drop_duplicates(subset=['First Name'], keep='last'))
# Out:
# 201

# %%
df.drop_duplicates(subset=['First Name', 'Team'], keep='last').head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron   Male 1994-01-29 2021-04-17 18:48:00   58755    5.097
# 937      Aaron    NaN 1986-01-22 2021-04-17 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2021-04-17 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2021-04-17 20:57:00  110194   14.727
# 538       Adam   Male 2010-10-08 2021-04-17 21:53:00   45181    3.491
#
#      Senior Management             Team
# 327               True        Marketing
# 937              False  Client Services
# 137              False     Distribution
# 141               True          Product
# 538              False  Human Resources

# %% [markdown]
# # Retrieve row values using loc() method in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['GoldenEye']
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['Diamonds are Forever': 'Moonracker']
# bond.loc['GoldenEye':]
# bond.loc[: "On Her Majesty's Secret Services"]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
#
#                        Budget  Bond Actor Salary
# Film
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1
# Goldfinger               18.6                3.2
# Licence to Kill          56.7                7.9
# Live and Let Die         30.8                NaN

# %%
bond.loc[["For Your Eyes Only", "Live and Let Die"]]
# Out:
#                     Year        Actor      Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore     John Glen       449.4    60.2
# Live and Let Die    1973  Roger Moore  Guy Hamilton       460.3    30.8
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN
# Live and Let Die                  NaN

# %% [markdown]
# #  Retrieve row values using iloc() method in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv')
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
# bond.loc[15]
bond.iloc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[[15,20]]
bond.iloc[:4]
bond.iloc[4:8]
bond.iloc[0:20:2]
# Out:
#                                Film  Year           Actor         Director  \
# 0                            Dr. No  1962    Sean Connery    Terence Young
# 2                        Goldfinger  1964    Sean Connery     Guy Hamilton
# 4                     Casino Royale  1967     David Niven       Ken Hughes
# 6   On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# 8                  Live and Let Die  1973     Roger Moore     Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore    Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore        John Glen
# 14                        Octopussy  1983     Roger Moore        John Glen
# 16             The Living Daylights  1987  Timothy Dalton        John Glen
# 18                        GoldenEye  1995  Pierce Brosnan  Martin Campbell
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 2        820.4    18.6                3.2
# 4        315.0    85.0                NaN
# 6        291.5    37.3                0.6
# 8        460.3    30.8                NaN
# 10       533.0    45.1                NaN
# 12       449.4    60.2                NaN
# 14       373.8    53.9                7.8
# 16       313.5    68.8                5.2
# 18       518.5    76.9                5.1

# %% [markdown]
# # Retrive row values using ix() methods in pandas

# %%
# In case of ix it has both the capability of loc and iloc
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
'Spectre' in bond.index
'Sacred Bond' in bond.index
bond.index
bond.values

# %% [markdown]
# # Second argument of iloc, loc and ix methods

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.loc['Moonraker', 'Actor']
# bond.loc['Moonraker', 'Director']
# bond.loc['Moonraker', 'Actor':'Budget']
bond.loc['Moonraker', ['Year', 'Director', 'Budget']]
# #Similarly we can use it with iloc and ix

# %% [markdown]
# # Set new values or a specific cell or Row in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %% [markdown]
# # Set Multiple values in DataFrames in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
mask=bond['Actor']=='Sean Connery'
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond[mask]['Actor']='Sir Sean Connery'
# Out:
# <ipython-input-43-f8905dde952e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bond[mask]['Actor']='Sir Sean Connery'

# %%
df2=bond[mask]
df2['Actor']='Sir Sean Connery'
df2
# Out:
# <ipython-input-44-db178bb61fc2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Actor']='Sir Sean Connery'
#                        Year             Actor        Director  Box Office  \
# Film
# Diamonds Are Forever   1971  Sir Sean Connery    Guy Hamilton       442.5
# Dr. No                 1962  Sir Sean Connery   Terence Young       448.8
# From Russia with Love  1963  Sir Sean Connery   Terence Young       543.8
# Goldfinger             1964  Sir Sean Connery    Guy Hamilton       820.4
# Never Say Never Again  1983  Sir Sean Connery  Irvin Kershner       380.0
# Thunderball            1965  Sir Sean Connery   Terence Young       848.1
# You Only Live Twice    1967  Sir Sean Connery   Lewis Gilbert       514.2
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Dr. No                    7.0                0.6
# From Russia with Love    12.6                1.6
# Goldfinger               18.6                3.2
# Never Say Never Again    86.0                NaN
# Thunderball              41.9                4.7
# You Only Live Twice      59.9                4.4

# %%
bond

# %% [markdown]
# # Rename Index Labels or Columns in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(columns={'Year':'Release date', 'Box Office' : 'Revenue'}, inplace=True)
bond.head()
# Out:
#                       Release date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(index={'Dr. No':'Doctor No', 'GoldenEye':'Golden Eye','The World Is Not Enough': 'Best Bond Movie'})
# Out:
#                                  Release date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Doctor No                                1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# Golden Eye                               1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# Octopussy                                1983     Roger Moore
# On Her Majesty's Secret Service          1969  George Lazenby
# Quantum of Solace                        2008    Daniel Craig
# Skyfall                                  2012    Daniel Craig
# Spectre                                  2015    Daniel Craig
# The Living Daylights                     1987  Timothy Dalton
# The Man with the Golden Gun              1974     Roger Moore
# The Spy Who Loved Me                     1977     Roger Moore
# Best Bond Movie                          1999  Pierce Brosnan
# Thunderball                              1965    Sean Connery
# Tomorrow Never Dies                      1997  Pierce Brosnan
# You Only Live Twice                      1967    Sean Connery
#
#                                            Director  Revenue  Budget  \
# Film
# A View to a Kill                          John Glen    275.2    54.5
# Casino Royale                       Martin Campbell    581.5   145.3
# Casino Royale                            Ken Hughes    315.0    85.0
# Diamonds Are Forever                   Guy Hamilton    442.5    34.7
# Die Another Day                        Lee Tamahori    465.4   154.2
# Doctor No                             Terence Young    448.8     7.0
# For Your Eyes Only                        John Glen    449.4    60.2
# From Russia with Love                 Terence Young    543.8    12.6
# Golden Eye                          Martin Campbell    518.5    76.9
# Goldfinger                             Guy Hamilton    820.4    18.6
# Licence to Kill                           John Glen    250.9    56.7
# Live and Let Die                       Guy Hamilton    460.3    30.8
# Moonraker                             Lewis Gilbert    535.0    91.5
# Never Say Never Again                Irvin Kershner    380.0    86.0
# Octopussy                                 John Glen    373.8    53.9
# On Her Majesty's Secret Service       Peter R. Hunt    291.5    37.3
# Quantum of Solace                      Marc Forster    514.2   181.4
# Skyfall                                  Sam Mendes    943.5   170.2
# Spectre                                  Sam Mendes    726.7   206.3
# The Living Daylights                      John Glen    313.5    68.8
# The Man with the Golden Gun            Guy Hamilton    334.0    27.7
# The Spy Who Loved Me                  Lewis Gilbert    533.0    45.1
# Best Bond Movie                       Michael Apted    439.5   158.3
# Thunderball                           Terence Young    848.1    41.9
# Tomorrow Never Dies              Roger Spottiswoode    463.2   133.9
# You Only Live Twice                   Lewis Gilbert    514.2    59.9
#
#                                  Bond Actor Salary
# Film
# A View to a Kill                               9.1
# Casino Royale                                  3.3
# Casino Royale                                  NaN
# Diamonds Are Forever                           5.8
# Die Another Day                               17.9
# Doctor No                                      0.6
# For Your Eyes Only                             NaN
# From Russia with Love                          1.6
# Golden Eye                                     5.1
# Goldfinger                                     3.2
# Licence to Kill                                7.9
# Live and Let Die                               NaN
# Moonraker                                      NaN
# Never Say Never Again                          NaN
# Octopussy                                      7.8
# On Her Majesty's Secret Service                0.6
# Quantum of Solace                              8.1
# Skyfall                                       14.5
# Spectre                                        NaN
# The Living Daylights                           5.2
# The Man with the Golden Gun                    NaN
# The Spy Who Loved Me                           NaN
# Best Bond Movie                               13.5
# Thunderball                                    4.7
# Tomorrow Never Dies                           10.0
# You Only Live Twice                            4.4

# %% [markdown]
# # Query Methods in Pandas

# %%
#Query methods only applys when all the column are strings and no space in between columns name

import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
bond.columns=[column_names.replace(" ",  "_") for column_names in bond.columns]
bond.head()
# Out:
#                       Year           Actor         Director  Box_Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond_Actor_Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.query('Actor=="Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.query("Director=='Terence Young'")
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Actor != 'Roger Moore'")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Never Say Never Again                 380.0    86.0                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.query("Box_Office>600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor=='Roger Moore' and Director=='John Glen'")
# Out:
#                     Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond_Actor_Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8
